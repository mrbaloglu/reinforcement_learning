# %%
import gym

from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env

# %%
# First, we create our environment called LunarLander-v2
env = gym.make("LunarLander-v2")

# Then we reset this environment
observation = env.reset()

for _ in range(20):
  # Take a random action
  action = env.action_space.sample()
  print("Action taken:", action)

  # Do this action in the environment and get
  # next_state, reward, done and info
  observation, reward, done, info = env.step(action)
  
  # If the game is done (in our case we land, crashed or timeout)
  if done:
      # Reset the environment
      print("Environment is reset")
      observation = env.reset()
# Out:
# Action taken: 2
# Action taken: 1
# Action taken: 0
# Action taken: 2
# Action taken: 3
# Action taken: 2
# Action taken: 0
# Action taken: 0
# Action taken: 0
# Action taken: 3
# Action taken: 2
# Action taken: 1
# Action taken: 1
# Action taken: 0
# Action taken: 0
# Action taken: 0
# Action taken: 3
# Action taken: 2
# Action taken: 2
# Action taken: 2

# %%
env = gym.make("LunarLander-v2")
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample()) # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape (8,)
# Sample observation [-0.6497116  -0.46800768  0.18354498  0.58861035  1.6862696   1.9854414
#  -0.04497052  2.2078469 ]

# %%
print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample()) # Take a random action
# Out:
#  _____ACTION SPACE_____
#
# Action Space Shape 4
# Action Space Sample 1

# %%
env = make_vec_env('LunarLander-v2', n_envs=16)

# %%
model = PPO(policy = 'MlpPolicy', env = env, n_steps = 1024, batch_size = 32, n_epochs = 10, gamma = 0.999, gae_lambda = 0.98,
    ent_coef = 0.01, verbose=1)
# Out:
# Using cpu device

# %%
# Train it for 500,000 timesteps
model.learn(total_timesteps=1000000)
# Save the model
model_name = "ppo-LunarLander-v2"
model.save(model_name)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93.5     |
# |    ep_rew_mean     | -182     |
# | time/              |          |
# |    fps             | 6195     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 16384    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.4        |
# |    ep_rew_mean          | -122        |
# | time/                   |             |
# |    fps                  | 1764        |
# |    iterations           | 2           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.007778799 |
# |    clip_fraction        | 0.0828      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.0015      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 847         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00703    |
# |    value_loss           | 2.71e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.9        |
# |    ep_rew_mean          | -107        |
# | time/                   |             |
# |    fps                  | 1563        |
# |    iterations           | 3           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009199081 |
# |    clip_fraction        | 0.0782      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.0522     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 633         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00669    |
# |    value_loss           | 737         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.9        |
# |    ep_rew_mean          | -88.6       |
# | time/                   |             |
# |    fps                  | 1451        |
# |    iterations           | 4           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008773249 |
# |    clip_fraction        | 0.0963      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.0225     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 471         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00603    |
# |    value_loss           | 543         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | -68.9       |
# | time/                   |             |
# |    fps                  | 1378        |
# |    iterations           | 5           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010505983 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.0014     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 104         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00873    |
# |    value_loss           | 382         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 110         |
# |    ep_rew_mean          | -52.2       |
# | time/                   |             |
# |    fps                  | 1357        |
# |    iterations           | 6           |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010763501 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | -3.91e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 114         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00723    |
# |    value_loss           | 297         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 123         |
# |    ep_rew_mean          | -40.8       |
# | time/                   |             |
# |    fps                  | 1343        |
# |    iterations           | 7           |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.010569286 |
# |    clip_fraction        | 0.0956      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | -2.92e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 168         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00707    |
# |    value_loss           | 273         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 133         |
# |    ep_rew_mean          | -27.4       |
# | time/                   |             |
# |    fps                  | 1291        |
# |    iterations           | 8           |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.008292092 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | -4.53e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 167         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00679    |
# |    value_loss           | 439         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 145          |
# |    ep_rew_mean          | -19          |
# | time/                   |              |
# |    fps                  | 1221         |
# |    iterations           | 9            |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0050522955 |
# |    clip_fraction        | 0.042        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | -8.34e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 143          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00239     |
# |    value_loss           | 547          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 197          |
# |    ep_rew_mean          | -8.03        |
# | time/                   |              |
# |    fps                  | 1171         |
# |    iterations           | 10           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0066697565 |
# |    clip_fraction        | 0.079        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 226          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00286     |
# |    value_loss           | 559          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 250         |
# |    ep_rew_mean          | 4.38        |
# | time/                   |             |
# |    fps                  | 1126        |
# |    iterations           | 11          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.009384939 |
# |    clip_fraction        | 0.0961      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 326         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00265    |
# |    value_loss           | 590         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 318         |
# |    ep_rew_mean          | 4.25        |
# | time/                   |             |
# |    fps                  | 1073        |
# |    iterations           | 12          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.009345122 |
# |    clip_fraction        | 0.0785      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 175         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.000702   |
# |    value_loss           | 534         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 350         |
# |    ep_rew_mean          | 1.75        |
# | time/                   |             |
# |    fps                  | 1018        |
# |    iterations           | 13          |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.006680372 |
# |    clip_fraction        | 0.0727      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 190         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00183    |
# |    value_loss           | 518         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 414         |
# |    ep_rew_mean          | 9.05        |
# | time/                   |             |
# |    fps                  | 981         |
# |    iterations           | 14          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.007380913 |
# |    clip_fraction        | 0.0969      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 114         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00381    |
# |    value_loss           | 437         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 502         |
# |    ep_rew_mean          | 20.5        |
# | time/                   |             |
# |    fps                  | 960         |
# |    iterations           | 15          |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.007914198 |
# |    clip_fraction        | 0.0745      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.557       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.9        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00313    |
# |    value_loss           | 132         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 588         |
# |    ep_rew_mean          | 35.1        |
# | time/                   |             |
# |    fps                  | 926         |
# |    iterations           | 16          |
# |    time_elapsed         | 282         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.008272573 |
# |    clip_fraction        | 0.0804      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.713       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.3        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00238    |
# |    value_loss           | 112         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 665        |
# |    ep_rew_mean          | 46.3       |
# | time/                   |            |
# |    fps                  | 903        |
# |    iterations           | 17         |
# |    time_elapsed         | 308        |
# |    total_timesteps      | 278528     |
# | train/                  |            |
# |    approx_kl            | 0.00884874 |
# |    clip_fraction        | 0.0706     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | 0.838      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 74.4       |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00305   |
# |    value_loss           | 100        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 756        |
# |    ep_rew_mean          | 57         |
# | time/                   |            |
# |    fps                  | 890        |
# |    iterations           | 18         |
# |    time_elapsed         | 331        |
# |    total_timesteps      | 294912     |
# | train/                  |            |
# |    approx_kl            | 0.00803447 |
# |    clip_fraction        | 0.0636     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.17      |
# |    explained_variance   | 0.903      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.14       |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.00251   |
# |    value_loss           | 74.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 818         |
# |    ep_rew_mean          | 66.8        |
# | time/                   |             |
# |    fps                  | 875         |
# |    iterations           | 19          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.006154314 |
# |    clip_fraction        | 0.0523      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.9        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00269    |
# |    value_loss           | 65.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 841          |
# |    ep_rew_mean          | 75.8         |
# | time/                   |              |
# |    fps                  | 861          |
# |    iterations           | 20           |
# |    time_elapsed         | 380          |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0076575773 |
# |    clip_fraction        | 0.0543       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.935        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 90.5         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 54.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 867         |
# |    ep_rew_mean          | 85.3        |
# | time/                   |             |
# |    fps                  | 849         |
# |    iterations           | 21          |
# |    time_elapsed         | 405         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.009117456 |
# |    clip_fraction        | 0.08        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.51        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00281    |
# |    value_loss           | 29.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 886          |
# |    ep_rew_mean          | 92.8         |
# | time/                   |              |
# |    fps                  | 841          |
# |    iterations           | 22           |
# |    time_elapsed         | 428          |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0046476126 |
# |    clip_fraction        | 0.0405       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.942        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.5         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 57.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 902          |
# |    ep_rew_mean          | 102          |
# | time/                   |              |
# |    fps                  | 828          |
# |    iterations           | 23           |
# |    time_elapsed         | 454          |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.0038059112 |
# |    clip_fraction        | 0.0409       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.922        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 321          |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00231     |
# |    value_loss           | 71.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 880         |
# |    ep_rew_mean          | 106         |
# | time/                   |             |
# |    fps                  | 820         |
# |    iterations           | 24          |
# |    time_elapsed         | 479         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.004489123 |
# |    clip_fraction        | 0.0522      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.75        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00305    |
# |    value_loss           | 21.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 888         |
# |    ep_rew_mean          | 109         |
# | time/                   |             |
# |    fps                  | 814         |
# |    iterations           | 25          |
# |    time_elapsed         | 502         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.005374682 |
# |    clip_fraction        | 0.0416      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.8        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00092    |
# |    value_loss           | 41.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 882         |
# |    ep_rew_mean          | 115         |
# | time/                   |             |
# |    fps                  | 804         |
# |    iterations           | 26          |
# |    time_elapsed         | 529         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.005976796 |
# |    clip_fraction        | 0.0486      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.2        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00129    |
# |    value_loss           | 39.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 879         |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 794         |
# |    iterations           | 27          |
# |    time_elapsed         | 556         |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.005588404 |
# |    clip_fraction        | 0.0418      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.6        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.000168   |
# |    value_loss           | 41.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 886         |
# |    ep_rew_mean          | 121         |
# | time/                   |             |
# |    fps                  | 790         |
# |    iterations           | 28          |
# |    time_elapsed         | 580         |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.005217351 |
# |    clip_fraction        | 0.0458      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.68        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.000866   |
# |    value_loss           | 38.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 870         |
# |    ep_rew_mean          | 121         |
# | time/                   |             |
# |    fps                  | 789         |
# |    iterations           | 29          |
# |    time_elapsed         | 601         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.005666107 |
# |    clip_fraction        | 0.0524      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.742       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00131    |
# |    value_loss           | 2.43        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 870          |
# |    ep_rew_mean          | 126          |
# | time/                   |              |
# |    fps                  | 784          |
# |    iterations           | 30           |
# |    time_elapsed         | 626          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0052655796 |
# |    clip_fraction        | 0.0444       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.997       |
# |    explained_variance   | 0.949        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.7         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | 7.59e-05     |
# |    value_loss           | 54.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 893         |
# |    ep_rew_mean          | 132         |
# | time/                   |             |
# |    fps                  | 781         |
# |    iterations           | 31          |
# |    time_elapsed         | 649         |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.004601455 |
# |    clip_fraction        | 0.0527      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.985      |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.2        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00134    |
# |    value_loss           | 34.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 915         |
# |    ep_rew_mean          | 135         |
# | time/                   |             |
# |    fps                  | 781         |
# |    iterations           | 32          |
# |    time_elapsed         | 671         |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.005003052 |
# |    clip_fraction        | 0.0681      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.981      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.541       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00185    |
# |    value_loss           | 2.49        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 930          |
# |    ep_rew_mean          | 136          |
# | time/                   |              |
# |    fps                  | 779          |
# |    iterations           | 33           |
# |    time_elapsed         | 693          |
# |    total_timesteps      | 540672       |
# | train/                  |              |
# |    approx_kl            | 0.0069786105 |
# |    clip_fraction        | 0.0509       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.962       |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.164        |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00147     |
# |    value_loss           | 1.51         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 915          |
# |    ep_rew_mean          | 136          |
# | time/                   |              |
# |    fps                  | 777          |
# |    iterations           | 34           |
# |    time_elapsed         | 716          |
# |    total_timesteps      | 557056       |
# | train/                  |              |
# |    approx_kl            | 0.0036556704 |
# |    clip_fraction        | 0.0406       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.937       |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.35         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0014      |
# |    value_loss           | 1.87         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 930          |
# |    ep_rew_mean          | 141          |
# | time/                   |              |
# |    fps                  | 776          |
# |    iterations           | 35           |
# |    time_elapsed         | 738          |
# |    total_timesteps      | 573440       |
# | train/                  |              |
# |    approx_kl            | 0.0036674931 |
# |    clip_fraction        | 0.0302       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.899       |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.67         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000689    |
# |    value_loss           | 24.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 949          |
# |    ep_rew_mean          | 147          |
# | time/                   |              |
# |    fps                  | 778          |
# |    iterations           | 36           |
# |    time_elapsed         | 758          |
# |    total_timesteps      | 589824       |
# | train/                  |              |
# |    approx_kl            | 0.0039559226 |
# |    clip_fraction        | 0.0495       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.849       |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.51         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00103     |
# |    value_loss           | 21.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 933          |
# |    ep_rew_mean          | 143          |
# | time/                   |              |
# |    fps                  | 774          |
# |    iterations           | 37           |
# |    time_elapsed         | 782          |
# |    total_timesteps      | 606208       |
# | train/                  |              |
# |    approx_kl            | 0.0039516864 |
# |    clip_fraction        | 0.0472       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.844       |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000835    |
# |    value_loss           | 38.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 919          |
# |    ep_rew_mean          | 142          |
# | time/                   |              |
# |    fps                  | 774          |
# |    iterations           | 38           |
# |    time_elapsed         | 803          |
# |    total_timesteps      | 622592       |
# | train/                  |              |
# |    approx_kl            | 0.0049770055 |
# |    clip_fraction        | 0.0558       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.843       |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.06         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00275     |
# |    value_loss           | 23           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 932         |
# |    ep_rew_mean          | 149         |
# | time/                   |             |
# |    fps                  | 775         |
# |    iterations           | 39          |
# |    time_elapsed         | 824         |
# |    total_timesteps      | 638976      |
# | train/                  |             |
# |    approx_kl            | 0.004196599 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.837      |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.519       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00135    |
# |    value_loss           | 35.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 920          |
# |    ep_rew_mean          | 150          |
# | time/                   |              |
# |    fps                  | 773          |
# |    iterations           | 40           |
# |    time_elapsed         | 846          |
# |    total_timesteps      | 655360       |
# | train/                  |              |
# |    approx_kl            | 0.0052559557 |
# |    clip_fraction        | 0.054        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.822       |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.253        |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000746    |
# |    value_loss           | 45.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 907          |
# |    ep_rew_mean          | 161          |
# | time/                   |              |
# |    fps                  | 772          |
# |    iterations           | 41           |
# |    time_elapsed         | 870          |
# |    total_timesteps      | 671744       |
# | train/                  |              |
# |    approx_kl            | 0.0037489198 |
# |    clip_fraction        | 0.0531       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.797       |
# |    explained_variance   | 0.947        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.2         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000775    |
# |    value_loss           | 88.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 871         |
# |    ep_rew_mean          | 174         |
# | time/                   |             |
# |    fps                  | 774         |
# |    iterations           | 42          |
# |    time_elapsed         | 888         |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.006700836 |
# |    clip_fraction        | 0.0928      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.77       |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 94.9        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00283    |
# |    value_loss           | 179         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 865          |
# |    ep_rew_mean          | 178          |
# | time/                   |              |
# |    fps                  | 772          |
# |    iterations           | 43           |
# |    time_elapsed         | 911          |
# |    total_timesteps      | 704512       |
# | train/                  |              |
# |    approx_kl            | 0.0039532427 |
# |    clip_fraction        | 0.0456       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.718       |
# |    explained_variance   | 0.907        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 187          |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 0.000188     |
# |    value_loss           | 177          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 815          |
# |    ep_rew_mean          | 190          |
# | time/                   |              |
# |    fps                  | 774          |
# |    iterations           | 44           |
# |    time_elapsed         | 931          |
# |    total_timesteps      | 720896       |
# | train/                  |              |
# |    approx_kl            | 0.0044390038 |
# |    clip_fraction        | 0.0548       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.726       |
# |    explained_variance   | 0.942        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8            |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000711    |
# |    value_loss           | 87.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 744         |
# |    ep_rew_mean          | 211         |
# | time/                   |             |
# |    fps                  | 774         |
# |    iterations           | 45          |
# |    time_elapsed         | 951         |
# |    total_timesteps      | 737280      |
# | train/                  |             |
# |    approx_kl            | 0.005158594 |
# |    clip_fraction        | 0.0607      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.699      |
# |    explained_variance   | 0.885       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 115         |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00194    |
# |    value_loss           | 201         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 652          |
# |    ep_rew_mean          | 221          |
# | time/                   |              |
# |    fps                  | 778          |
# |    iterations           | 46           |
# |    time_elapsed         | 967          |
# |    total_timesteps      | 753664       |
# | train/                  |              |
# |    approx_kl            | 0.0069310516 |
# |    clip_fraction        | 0.0789       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.679       |
# |    explained_variance   | 0.849        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 197          |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00291     |
# |    value_loss           | 262          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 455          |
# |    ep_rew_mean          | 245          |
# | time/                   |              |
# |    fps                  | 781          |
# |    iterations           | 47           |
# |    time_elapsed         | 984          |
# |    total_timesteps      | 770048       |
# | train/                  |              |
# |    approx_kl            | 0.0052088713 |
# |    clip_fraction        | 0.0721       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.688       |
# |    explained_variance   | 0.799        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 190          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00177     |
# |    value_loss           | 326          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 357         |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 785         |
# |    iterations           | 48          |
# |    time_elapsed         | 1001        |
# |    total_timesteps      | 786432      |
# | train/                  |             |
# |    approx_kl            | 0.007709026 |
# |    clip_fraction        | 0.0825      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.704      |
# |    explained_variance   | 0.777       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 179         |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0033     |
# |    value_loss           | 261         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 311         |
# |    ep_rew_mean          | 261         |
# | time/                   |             |
# |    fps                  | 789         |
# |    iterations           | 49          |
# |    time_elapsed         | 1017        |
# |    total_timesteps      | 802816      |
# | train/                  |             |
# |    approx_kl            | 0.010852329 |
# |    clip_fraction        | 0.0761      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.759      |
# |    explained_variance   | 0.785       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 57.2        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00329    |
# |    value_loss           | 143         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 287         |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 792         |
# |    iterations           | 50          |
# |    time_elapsed         | 1033        |
# |    total_timesteps      | 819200      |
# | train/                  |             |
# |    approx_kl            | 0.004964031 |
# |    clip_fraction        | 0.0593      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.763      |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.9        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00106    |
# |    value_loss           | 96          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 282          |
# |    ep_rew_mean          | 263          |
# | time/                   |              |
# |    fps                  | 794          |
# |    iterations           | 51           |
# |    time_elapsed         | 1051         |
# |    total_timesteps      | 835584       |
# | train/                  |              |
# |    approx_kl            | 0.0050957627 |
# |    clip_fraction        | 0.0526       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.787       |
# |    explained_variance   | 0.733        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.5         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00148     |
# |    value_loss           | 173          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 397        |
# |    ep_rew_mean          | 236        |
# | time/                   |            |
# |    fps                  | 787        |
# |    iterations           | 52         |
# |    time_elapsed         | 1081       |
# |    total_timesteps      | 851968     |
# | train/                  |            |
# |    approx_kl            | 0.06392422 |
# |    clip_fraction        | 0.0957     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.792     |
# |    explained_variance   | 0.828      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.87       |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.000421  |
# |    value_loss           | 138        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 513         |
# |    ep_rew_mean          | 214         |
# | time/                   |             |
# |    fps                  | 782         |
# |    iterations           | 53          |
# |    time_elapsed         | 1109        |
# |    total_timesteps      | 868352      |
# | train/                  |             |
# |    approx_kl            | 0.007239858 |
# |    clip_fraction        | 0.0497      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.819      |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.9        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00185    |
# |    value_loss           | 24.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 628         |
# |    ep_rew_mean          | 189         |
# | time/                   |             |
# |    fps                  | 778         |
# |    iterations           | 54          |
# |    time_elapsed         | 1136        |
# |    total_timesteps      | 884736      |
# | train/                  |             |
# |    approx_kl            | 0.014081276 |
# |    clip_fraction        | 0.0978      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.855      |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.62        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00281    |
# |    value_loss           | 7.21        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 738          |
# |    ep_rew_mean          | 162          |
# | time/                   |              |
# |    fps                  | 775          |
# |    iterations           | 55           |
# |    time_elapsed         | 1162         |
# |    total_timesteps      | 901120       |
# | train/                  |              |
# |    approx_kl            | 0.0060489825 |
# |    clip_fraction        | 0.0543       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.871       |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.85         |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00171     |
# |    value_loss           | 4.8          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 845         |
# |    ep_rew_mean          | 139         |
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 56          |
# |    time_elapsed         | 1187        |
# |    total_timesteps      | 917504      |
# | train/                  |             |
# |    approx_kl            | 0.006729191 |
# |    clip_fraction        | 0.0791      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.84       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.17        |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00336    |
# |    value_loss           | 5.69        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 968          |
# |    ep_rew_mean          | 119          |
# | time/                   |              |
# |    fps                  | 768          |
# |    iterations           | 57           |
# |    time_elapsed         | 1215         |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0058633657 |
# |    clip_fraction        | 0.0726       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.831       |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.09         |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00334     |
# |    value_loss           | 7.62         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 955          |
# |    ep_rew_mean          | 134          |
# | time/                   |              |
# |    fps                  | 766          |
# |    iterations           | 58           |
# |    time_elapsed         | 1240         |
# |    total_timesteps      | 950272       |
# | train/                  |              |
# |    approx_kl            | 0.0053405515 |
# |    clip_fraction        | 0.0618       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.764       |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.88         |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.00271     |
# |    value_loss           | 5.29         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 874          |
# |    ep_rew_mean          | 165          |
# | time/                   |              |
# |    fps                  | 766          |
# |    iterations           | 59           |
# |    time_elapsed         | 1261         |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0048706154 |
# |    clip_fraction        | 0.0705       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.703       |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.83         |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.00373     |
# |    value_loss           | 34.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 771         |
# |    ep_rew_mean          | 198         |
# | time/                   |             |
# |    fps                  | 766         |
# |    iterations           | 60          |
# |    time_elapsed         | 1283        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.010089152 |
# |    clip_fraction        | 0.0959      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.671      |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.02        |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.00478    |
# |    value_loss           | 55          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 565         |
# |    ep_rew_mean          | 240         |
# | time/                   |             |
# |    fps                  | 767         |
# |    iterations           | 61          |
# |    time_elapsed         | 1302        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.006575296 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.66       |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.3        |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00362    |
# |    value_loss           | 103         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 348         |
# |    ep_rew_mean          | 269         |
# | time/                   |             |
# |    fps                  | 770         |
# |    iterations           | 62          |
# |    time_elapsed         | 1318        |
# |    total_timesteps      | 1015808     |
# | train/                  |             |
# |    approx_kl            | 0.024245583 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.643      |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.7        |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.00577    |
# |    value_loss           | 109         |
# -----------------------------------------

# %%
eval_env = gym.make("LunarLander-v2")
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=265.18 +/- 25.747441325450193

# %%
from colabgymrender.recorder import Recorder

directory = './video'
env = Recorder(eval_env, directory)

obs = env.reset()
done = False
while not done:
  action, _state = model.predict(obs)
  obs, reward, done, info = env.step(action)
env.play()
# Out:
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/9y/0_p75b4j0dvfw0qn8l2qvyfh0000gn/T/ipykernel_31341/1523563896.py in <module>
#       9   action, _state = model.predict(obs)
#      10   obs, reward, done, info = env.step(action)
# ---> 11 env.play()
#
# /opt/anaconda3/envs/inferno/lib/python3.7/site-packages/colabgymrender/recorder.py in play(self)
#      70         filename = 'temp-{start}.mp4'
#      71         clip = VideoFileClip(self.path)
# ---> 72         clip.write_videofile(filename, progress_bar = False, verbose = False)
#      73         display(Video(filename, embed = True))
#      74         os.remove(filename)
#
# /opt/anaconda3/envs/inferno/lib/python3.7/site-packages/decorator.py in fun(*args, **kw)
#     229     """
#     230     evaldict = dict(_call_=caller, _func_=func)
# --> 231     es = ''
#     232     for i, extra in enumerate(extras):
#     233         ex = '_e%d_' % i
#
# /opt/anaconda3/envs/inferno/lib/python3.7/site-packages/decorator.py in fix(args, kwargs, sig)
#     201         evaldict is the evaluation dictionary. If addsource is true an
#     202         attribute __source__ is added to the result. The attributes attrs
# --> 203         are added, if any.
#     204         """
#     205         if isinstance(obj, str):  # "name(signature)"
#
# /opt/anaconda3/envs/inferno/lib/python3.7/inspect.py in bind(*args, **kwargs)
#    3013         if the passed arguments can not be bound.
#    3014         """
# -> 3015         return args[0]._bind(args[1:], kwargs)
#    3016
#    3017     def bind_partial(*args, **kwargs):
#
# /opt/anaconda3/envs/inferno/lib/python3.7/inspect.py in _bind(self, args, kwargs, partial)
#    3004                 raise TypeError(
#    3005                     'got an unexpected keyword argument {arg!r}'.format(
# -> 3006                         arg=next(iter(kwargs))))
#    3007
#    3008         return self._bound_arguments_cls(self, arguments)
#
# TypeError: got an unexpected keyword argument 'progress_bar'
